# %%
import os

# %%
DIRECTORY_NAME = "text"

# %%
filenames = {int(i.split("_")[0]): i for i in os.listdir(DIRECTORY_NAME)}
sorted_filenames = []
for i in range(1, len(filenames)+1):
    sorted_filenames.append(filenames[i])

# %%
sorted_filenames
# Out:
# ['1_0000.txt',
#  '2_0011.txt',
#  '3_0022.txt',
#  '4_0033.txt',
#  '5_0044.txt',
#  '6_0054.txt',
#  '7_0055.txt',
#  '8_0056.txt',
#  '9_0057.txt',
#  '10_0001.txt',
#  '11_0002.txt',
#  '12_0003.txt',
#  '13_0004.txt',
#  '14_0005.txt',
#  '15_0006.txt',
#  '16_0007.txt',
#  '17_0008.txt',
#  '18_0009.txt',
#  '19_0010.txt',
#  '20_0012.txt',
#  '21_0013.txt',
#  '22_0014.txt',
#  '23_0015.txt',
#  '24_0016.txt',
#  '25_0017.txt',
#  '26_0018.txt',
#  '27_0019.txt',
#  '28_0020.txt',
#  '29_0021.txt',
#  '30_0023.txt',
#  '31_0024.txt',
#  '32_0025.txt',
#  '33_0026.txt',
#  '34_0027.txt',
#  '35_0028.txt',
#  '36_0029.txt',
#  '37_0030.txt',
#  '38_0031.txt',
#  '39_0032.txt',
#  '40_0034.txt',
#  '41_0035.txt',
#  '42_0036.txt',
#  '43_0037.txt',
#  '44_0038.txt',
#  '45_0039.txt',
#  '46_0040.txt',
#  '47_0041.txt',
#  '48_0042.txt',
#  '49_0043.txt',
#  '50_0045.txt',
#  '51_0046.txt',
#  '52_0047.txt',
#  '53_0048.txt',
#  '54_0049.txt',
#  '55_0050.txt',
#  '56_0051.txt',
#  '57_0052.txt',
#  '58_0053.txt']

# %%
import codecs


def read_text(filename):
    with codecs.open(os.path.join(DIRECTORY_NAME, filename), "r", encoding="utf-8") as f:
        return f.read()


def split_page(text):
    return [i.replace("\n", " ") for i in text.split(".\n")]


class Abbreviations:
    B = "B."
    M = "M."
    MC = "M.C."
    MT = "M.T."
    SAT = "S.A.T."
    COMM = "Comm."
    CONF = "Conf."
    CORRESP = "Corresp."
    PUBLIC = "Public."
    FAM = "Fam."
    ILL = "Ill."
    SQ = "sq."

import re

class Extractor:

    @staticmethod
    def extract_citation(text: str):
        """
        >>> "Abilly - Archéolab, B.2002, 9 - Forges, B.1996, 669 ; sidérurgie, voir Guichard - Habitat, voir Rousseau - Néolithique, voir Marquet - Tessons protohistoriques, voir Geslin et Schoenstein - Lieux-dits : Le Fouion, fouilles 1994 : voir Millet-Richard ; B.2000, 382 - Le Petit- Paulmy, B.1997, 344 ; B.2000, 382 - Site de la Grosse Coue, voir Millet-Richard"

        :param text:
        :return:
        """
        l = []

        bulletin_pattern = re.compile(r"B\.( )?(?P<year>[0-9]+), (?P<page>[0-9]+)( sq\.)?")
        m = bulletin_pattern.search(text)
        while m:
            l.append(dict(work=Abbreviations.B, year=m.group("year"), page=m.group("page")))
            beginning_i = m.end() + 1
            m = bulletin_pattern.search(text, pos=beginning_i)

        memoire_pattern = re.compile(r"M\.( )?(?P<number>[IVXLCDM]+), (?P<page>[0-9]+)(sq\.)?")
        m = memoire_pattern.search(text)
        while m:
            l.append(dict(work=Abbreviations.M, number=m.group("number"), page=m.group("page")))
            beginning_i = m.end() + 1
            m = memoire_pattern.search(text, pos=beginning_i)
        return l

    @staticmethod
    def extract_named_entity(text: str):
        """
        >>> "Abilly - Archéolab, B.2002, 9 - Forges, B.1996, 669 ; sidérurgie, voir Guichard - Habitat, voir Rousseau - Néolithique, voir Marquet - Tessons protohistoriques, voir Geslin et Schoenstein - Lieux-dits : Le Fouion, fouilles 1994 : voir Millet-Richard ; B.2000, 382 - Le Petit- Paulmy, B.1997, 344 ; B.2000, 382 - Site de la Grosse Coue, voir Millet-Richard"

        :param text:
        :return:
        """
        named_entity = text.split(" - ")[0]

        return named_entity

    @staticmethod
    def see_this(text: str):
        l = []
        bulletin_pattern = re.compile(r"voir( aussi)? (?P<named_entity>[ \w]+)")
        m = bulletin_pattern.search(text)
        while m:
            l.append(dict(named_entity=m.group("named_entity")))
            beginning_i = m.end() + 1
            m = bulletin_pattern.search(text, pos=beginning_i)

# %%
pages = []
for filename in sorted_filenames:
    text = read_text(filename)
    pages.extend([split_page(page) for page in text.split("\n\n") if page])

# %%
#pages[0:2]

# %%
for i, page in enumerate(pages):
    for entry in page:
        citations = Extractor.extract_citation(entry)
        if citations:
            print(i+1, Extractor.extract_named_entity(entry), citations)
# Out:
# 1 A Abbeville [{'work': 'M.', 'number': 'LXIII', 'page': '167'}]
# 1 ABD-EL-KADER [{'work': 'B.', 'year': '2000', 'page': '403'}]
# 1 Abilly [{'work': 'B.', 'year': '2002', 'page': '9'}, {'work': 'B.', 'year': '1996', 'page': '669'}, {'work': 'B.', 'year': '2000', 'page': '382'}, {'work': 'B.', 'year': '1997', 'page': '344'}, {'work': 'B.', 'year': '2000', 'page': '382'}]
# 1 Ablevois [{'work': 'M.', 'number': 'LXII', 'page': '113'}]
# 1 Abreuvoir [{'work': 'B.', 'year': '2002', 'page': '51'}]
# 1 Abysme de Candes (l') [{'work': 'M.', 'number': 'LXII', 'page': '120'}]
# 1 Académie des Sciences, Arts et Belles-Lettres de Touraine [{'work': 'B.', 'year': '1994', 'page': '69'}]
# 1 Académie française [{'work': 'B.', 'year': '2003', 'page': '171'}]
# 1 ACHON (François d') [{'work': 'B.', 'year': '1997', 'page': '75'}]
# 1 1998, 384, 671 [{'work': 'B.', 'year': '1997', 'page': '350'}]
# 1 ACIGNÉ (Anne-Marguerite d’} [{'work': 'B.', 'year': '2001', 'page': '209'}]
# 1 ADALARD [{'work': 'M.', 'number': 'LXIL', 'page': '45'}]
# 1 ADALBERON, évêque de Reims [{'work': 'M.', 'number': 'LXII', 'page': '49'}]
# 1 ADALBERT, évêque de Prague [{'work': 'B.', 'year': '1995', 'page': '612'}]
# 1 Adam (Philippe) [{'work': 'B.', 'year': '1997', 'page': '40'}]
# 1 ADHÉMAR DE MONTFALCON (Jean-Balthazar d')- B.1998, 509 [{'work': 'B.', 'year': '1998', 'page': '509'}]
# 1 ADRIAENSIS DE CAZAN [{'work': 'B.', 'year': '1995', 'page': '478'}]
# 1 ADRIAENSIS DE CAZAN (Gabrielle-Jeanne) [{'work': 'B.', 'year': '1995', 'page': '478'}]
# 1 ADRIEN I, pape [{'work': 'B.', 'year': '1995', 'page': '423'}]
# 1 Aigronne [{'work': 'B.', 'year': '1996', 'page': '687'}]
# 1 Aiguevives, abbaye [{'work': 'B.', 'year': '2000', 'page': '227'}]
# 1 AILLERET [{'work': 'B.', 'year': '2003', 'page': '222'}]
# 1 AKERMANN -B.1997, 272 [{'work': 'B.', 'year': '1997', 'page': '272'}]
# 1 ALARIC, moine [{'work': 'M.', 'number': 'LXII', 'page': '44'}]
# 1 ALARIC [{'work': 'B.', 'year': '1997', 'page': '125'}]
# 2  France", B.1994 323: "Révélations exclusives sur la période de l'Occupation en Touraine", B.1994, 42: "La vallée de l’Tndre sous le joug allemand", B.1995, 600 [{'work': 'B.', 'year': '1994', 'page': '42'}, {'work': 'B.', 'year': '1995', 'page': '600'}]
# 2 ALBERT (famille d’) [{'work': 'B.', 'year': '2000', 'page': '310'}, {'work': 'B.', 'year': '2002', 'page': '111'}]
# 2 ALBERT (Louis-Charles d”) [{'work': 'B.', 'year': '2000', 'page': '309'}]
# 2 ALBIACH (Marie)- Public. : "L’habitat troglo- dytique en Touraine et dans le Saumurois", B.2001, 224 [{'work': 'B.', 'year': '2001', 'page': '224'}]
# 2 ALBINUS, évêque [{'work': 'M.', 'number': 'LXIII', 'page': '236'}]
# 2 ALCUIN, abbé de Cormery [{'work': 'B.', 'year': '1994', 'page': '120'}, {'work': 'B.', 'year': '1995', 'page': '551'}, {'work': 'B.', 'year': '1997', 'page': '134'}, {'work': 'B.', 'year': '2001', 'page': '39'}, {'work': 'B.', 'year': '1995', 'page': '453'}, {'work': 'M.', 'number': 'LXIII', 'page': '231'}]
# 2 ALEXANDRE III pape [{'work': 'B.', 'year': '1995', 'page': '612'}]
# 2 ALEXANDRE VI, pape [{'work': 'B.', 'year': '1995', 'page': '428'}, {'work': 'M.', 'number': 'LXII', 'page': '53'}]
# 2 ALEXIS (Stéphanie) [{'work': 'B.', 'year': '2002', 'page': '197'}]
# 2 ALFANTI (Elena) [{'work': 'B.', 'year': '2001', 'page': '220'}, {'work': 'M.', 'number': 'LXII', 'page': '249'}]
# 2 ALILAIRE (Pascal) [{'work': 'B.', 'year': '2000', 'page': '137'}, {'work': 'B.', 'year': '1997', 'page': '343'}, {'work': 'B.', 'year': '1998', 'page': '661'}, {'work': 'B.', 'year': '2001', 'page': '201'}, {'work': 'B.', 'year': '1999', 'page': '735'}, {'work': 'M.', 'number': 'LXIV', 'page': '129'}]
# 2 ALLAIN-DUPRÉ, médecin [{'work': 'B.', 'year': '2000', 'page': '343'}]
# 2 ALLAIN (Marguerite) [{'work': 'B.', 'year': '1995', 'page': '489'}]
# 2 ALLARD (Eric) [{'work': 'B.', 'year': '1995', 'page': '594'}]
# 2 ALLEAUME (Pierre) [{'work': 'B.', 'year': '2003', 'page': '162'}]
# 2 ALLIBERT (famille) [{'work': 'B.', 'year': '1997', 'page': '264'}]
# 4  Allonnes [{'work': 'B.', 'year': '1998', 'page': '366'}]
# 4 ALLUYE (Hugues d') [{'work': 'B.', 'year': '2001', 'page': '201'}]
# 4 ALLUYE (Jean d’} [{'work': 'B.', 'year': '2001', 'page': '205'}]
# 4 ALPHAND (Adolphe) [{'work': 'B.', 'year': '1997', 'page': '267'}]
# 4 ALVÈS d'OLIVEIRA CA.) [{'work': 'B.', 'year': '2000', 'page': '385'}]
# 4 AMANDUS [{'work': 'M.', 'number': 'LXIII', 'page': '230'}]
# 4 Amasse [{'work': 'B.', 'year': '1996', 'page': '684'}]
# 4 Ambacia [{'work': 'B.', 'year': '2003', 'page': '38'}, {'work': 'M.', 'number': 'LXIV', 'page': '129'}]
# 4 Ambillou [{'work': 'B.', 'year': '1997', 'page': '160'}, {'work': 'B.', 'year': '1997', 'page': '264'}]
# 4 Amboise [{'work': 'B.', 'year': '1999', 'page': '1015'}, {'work': 'B.', 'year': '1998', 'page': '662'}, {'work': 'B.', 'year': '1995', 'page': '358'}, {'work': 'B.', 'year': '1996', 'page': '811'}, {'work': 'B.', 'year': '1999', 'page': '1031'}, {'work': 'B.', 'year': '2000', 'page': '403'}, {'work': 'B.', 'year': '1995', 'page': '451'}, {'work': 'B.', 'year': '1997', 'page': '260'}, {'work': 'B.', 'year': '1996', 'page': '809'}, {'work': 'B.', 'year': '1995', 'page': '335'}, {'work': 'B.', 'year': '1995', 'page': '359'}, {'work': 'B.', 'year': '1997', 'page': '125'}, {'work': 'B.', 'year': '2002', 'page': '82'}, {'work': 'B.', 'year': '1997', 'page': '45'}, {'work': 'B.', 'year': '1999', 'page': '1034'}, {'work': 'B.', 'year': '1997', 'page': '323'}, {'work': 'B.', 'year': '1994', 'page': '275'}, {'work': 'B.', 'year': '1999', 'page': '691'}, {'work': 'B.', 'year': '1999', 'page': '1015'}, {'work': 'B.', 'year': '2000', 'page': '369'}, {'work': 'M.', 'number': 'LXIV', 'page': '6'}]
# 5  -6- vignerons et le marché immobilier, voir Jollet [{'work': 'B.', 'year': '1998', 'page': '578'}, {'work': 'B.', 'year': '1999', 'page': '1030'}, {'work': 'B.', 'year': '2000', 'page': '391'}, {'work': 'B.', 'year': '2001', 'page': '209'}, {'work': 'B.', 'year': '1996', 'page': '915'}, {'work': 'B.', 'year': '1997', 'page': '169'}, {'work': 'M.', 'number': 'LXIL', 'page': '13'}]
# 5 AMBOISE (cardinal d’} [{'work': 'B.', 'year': '2001', 'page': '112'}, {'work': 'B.', 'year': '2001', 'page': '115'}]
# 5 AMBOISE {Ingelger I le Grand) [{'work': 'B.', 'year': '2000', 'page': '162'}]
# 5 AMBOISE (Ingelger II d”) [{'work': 'B.', 'year': '2000', 'page': '162'}]
# 5 AMBOISE (Lisois d°) [{'work': 'B.', 'year': '2000', 'page': '162'}]
# 5 AMBOISE (Louis d’) [{'work': 'M.', 'number': 'LXII', 'page': '121'}]
# 5 AMBOISE (Mathilde d”) [{'work': 'B.', 'year': '2002', 'page': '132'}]
# 5 AMBOISE (Pierre d°) [{'work': 'B.', 'year': '1998', 'page': '658'}, {'work': 'B.', 'year': '2000', 'page': '162'}]
# 5 AMBOISE (Sulpice Il d°) [{'work': 'B.', 'year': '2000', 'page': '162'}, {'work': 'B.', 'year': '2002', 'page': '132'}]
# 5 AMELOT DE CHAILLOU [{'work': 'B.', 'year': '1999', 'page': '1036'}]
# 5 AMELOT DE GOURNAY (Michel), archevêque de Tours, B.1997, 202 ; B.1999, 971 [{'work': 'B.', 'year': '1997', 'page': '202'}, {'work': 'B.', 'year': '1999', 'page': '971'}]
# 5 Amirault (Jacques) [{'work': 'B.', 'year': '1995', 'page': '594'}, {'work': 'B.', 'year': '1995', 'page': '594'}, {'work': 'B.', 'year': '1999', 'page': '1016'}]
# 5 Amoureux du Vieux Langeais [{'work': 'B.', 'year': '2003', 'page': '237'}, {'work': 'B.', 'year': '2002', 'page': '172'}]
# 5 ANACLET IL, antipape [{'work': 'M.', 'number': 'LXII', 'page': '128'}]
# 5 Anché [{'work': 'B.', 'year': '2000', 'page': '401'}, {'work': 'B.', 'year': '2000', 'page': '401'}]
# 5 ANDRAULT (Claude), fermier de l’abbaye de Cormery, époux de Renée Baleschoux, B.1995, 538 [{'work': 'B.', 'year': '1995', 'page': '538'}]
# 5 ANDRÉ Œdouard), architecte de jardins [{'work': 'B.', 'year': '1994', 'page': '204'}, {'work': 'B.', 'year': '1997', 'page': '267'}]
# 5 ANDRÉ Florence) [{'work': 'B.', 'year': '2001', 'page': '223'}, {'work': 'B.', 'year': '1999', 'page': '1019'}]
# 5 ANDROUET DU CERCEAU (Jacques I } [{'work': 'B.', 'year': '2000', 'page': '352'}]
# 5 ANDROUET DU CERCEAU (Jacques Il) [{'work': 'B.', 'year': '2000', 'page': '353'}]
# 6 ANDURAND (Olivier) [{'work': 'B.', 'year': '2002', 'page': '198'}]
# 6 Anet [{'work': 'B.', 'year': '1998', 'page': '612'}]
# 6 Angé (Loir-et-Cher) [{'work': 'M.', 'number': 'LXIV', 'page': '132'}]
# 6 Aniaca (Loir-et-Cher) [{'work': 'M.', 'number': 'LXIV', 'page': '132'}]
# 6 ANGELLIER (famille) [{'work': 'B.', 'year': '1997', 'page': '264'}]
# 6 Angers [{'work': 'M.', 'number': 'LXIX', 'page': '51'}]
# 6 Angles-sur-l'Anglin [{'work': 'B.', 'year': '2000', 'page': '217'}, {'work': 'B.', 'year': '1998', 'page': '377'}, {'work': 'B.', 'year': '1998', 'page': '378'}, {'work': 'B.', 'year': '1998', 'page': '378'}]
# 6 Anjerand (Abel et Mme) [{'work': 'B.', 'year': '2003', 'page': '37'}]
# 6 Anjou [{'work': 'B.', 'year': '1995', 'page': '416'}]
# 6 ANJOU (Charles d’} [{'work': 'B.', 'year': '2000', 'page': '163'}]
# 6 ANJOU (Philippe d’} [{'work': 'B.', 'year': '1996', 'page': '847'}]
# 6 ANTHEAUME (Nicolas) [{'work': 'B.', 'year': '2000', 'page': '343'}]
# 6 ANTHONIOZ {docteur} [{'work': 'B.', 'year': '1997', 'page': '287'}]
# 6 Anügny [{'work': 'B.', 'year': '1998', 'page': '377'}, {'work': 'B.', 'year': '1998', 'page': '377'}, {'work': 'B.', 'year': '1998', 'page': '377'}]
# 6 Antogny-le-Tillac [{'work': 'B.', 'year': '1999', 'page': '853'}, {'work': 'B.', 'year': '1999', 'page': '856'}, {'work': 'B.', 'year': '1997', 'page': '166'}]
# 6 Antoigné [{'work': 'B.', 'year': '2000', 'page': '258'}]
# 6 Aoste [{'work': 'M.', 'number': 'LXII', 'page': '260'}, {'work': 'M.', 'number': 'LXIII', 'page': '260'}, {'work': 'M.', 'number': 'LXII', 'page': '2615'}]
# 6 APVRIL (Eustache) [{'work': 'B.', 'year': '1995', 'page': '454'}]
# 6 Aquilon (Pierre) [{'work': 'B.', 'year': '1998', 'page': '665'}]
# 7 7 ARBORIUS [{'work': 'B.', 'year': '1997', 'page': '103'}]
# 7 Ârbre de Saint Martin [{'work': 'M.', 'number': 'LXII', 'page': '188'}]
# 7 ARBRISSEL (Robert d’) [{'work': 'B.', 'year': '2000', 'page': '258'}]
# 7 ARCHAMBAULT (abbé) [{'work': 'B.', 'year': '2001', 'page': '174'}]
# 7 ARCHAMBAULT (François) [{'work': 'B.', 'year': '1999', 'page': '1004'}]
# 7 ARCHAMBAULT (Gabriel), valet, assassiné, B.1995, 526 [{'work': 'B.', 'year': '1995', 'page': '526'}]
# 7 ARCHAMBAULT (Pierre) [{'work': 'B.', 'year': '2000', 'page': '370'}]
# 7 ARCHDEACON (famille) [{'work': 'B.', 'year': '1997', 'page': '264'}]
# 7 Archéologie [{'work': 'B.', 'year': '2003', 'page': '21'}]
# 7 Archéologie aérienne [{'work': 'B.', 'year': '1996', 'page': '739'}]
# 7 Architecture civile à Tours des origines à la Renaissance [{'work': 'M.', 'number': 'X', 'page': '1'}]
# 7 Ardillière [{'work': 'B.', 'year': '1996', 'page': '682'}]
# 7 ARDON [{'work': 'B.', 'year': '2001', 'page': '40'}]
# 7 ARDOUIN-WEISS (Idelette) [{'work': 'B.', 'year': '1998', 'page': '665'}]
# 7 Arieta (Alice) [{'work': 'B.', 'year': '1994', 'page': '47'}]
# 7 Argenton-sur-Creuse [{'work': 'B.', 'year': '1999', 'page': '908'}, {'work': 'B.', 'year': '1999', 'page': '693'}]
# 7 ARGOUGES (Martin d’} [{'work': 'B.', 'year': '2002', 'page': '78'}]
# 7 Ariaco [{'work': 'M.', 'number': 'LXIV', 'page': '132'}]
# 7 ARIUS [{'work': 'M.', 'number': 'LXII', 'page': '23'}]
# 7 ARLOT (Henri d’) [{'work': 'B.', 'year': '1998', 'page': '650'}]
# 7 ARMAGNAC (Jean d’), conseilier d'Etat, époux Daviot, B.1996, 669 [{'work': 'B.', 'year': '1996', 'page': '669'}]
# 7 ARMAGNAC (Marie d’), épouse de Jacques Rabault, B.1995, 527 sq [{'work': 'B.', 'year': '1995', 'page': '527'}]
# 7 ARMAGNAC (Mathieu-Pierre d”} [{'work': 'B.', 'year': '1995', 'page': '527'}]
# 9 Armand (M. Mme Pierre) [{'work': 'B.', 'year': '1994', 'page': '71'}]
# 9 ARNAUD (docteur) [{'work': 'B.', 'year': '1999', 'page': '1005'}]
# 9 ARNAUD (E) [{'work': 'B.', 'year': '1998', 'page': '665'}]
# 9 ARNAULT (Yves ou Yvette) [{'work': 'B.', 'year': '2002', 'page': '200'}, {'work': 'B.', 'year': '2003', 'page': '235'}, {'work': 'B.', 'year': '1995', 'page': '426'}]
# 10 ARNOULT (Julien) [{'work': 'B.', 'year': '1996', 'page': '968'}]
# 10 ARON (Emile) [{'work': 'B.', 'year': '1994', 'page': '322'}, {'work': 'B.', 'year': '1996', 'page': '651'}, {'work': 'B.', 'year': '2000', 'page': '388'}, {'work': 'B.', 'year': '1999', 'page': '1021'}]
# 10 Arpheuilles [{'work': 'B.', 'year': '2000', 'page': '220'}]
# 10 ARSAGUS, évêque de Nice [{'work': 'B.', 'year': '1995', 'page': '453'}]
# 10 Arsicaud (Robert) [{'work': 'B.', 'year': '1996', 'page': '672'}]
# 10 Art et Poésie de Touraine [{'work': 'B.', 'year': '1994', 'page': '69'}]
# 10 Artannes [{'work': 'B.', 'year': '2000', 'page': '370'}, {'work': 'M.', 'number': 'LXIV', 'page': '86'}]
# 10 Artigny [{'work': 'B.', 'year': '2000', 'page': '371'}]
# 10 Arville [{'work': 'B.', 'year': '1995', 'page': '358'}]
# 10 Asfeld (M. et Mme d’} [{'work': 'B.', 'year': '1998', 'page': '383'}]
# 10 Asnières-sur-Vêgre [{'work': 'B.', 'year': '1994', 'page': '51'}]
# 10 Assay [{'work': 'B.', 'year': '2000', 'page': '385'}, {'work': 'M.', 'number': 'LXIV', 'page': '76'}]
# 10 Assise (Italie) [{'work': 'M.', 'number': 'LXIII', 'page': '177'}]
# 10 Association archéologique des amis de René Gaïloux [{'work': 'B.', 'year': '1995', 'page': '341'}]
# 10 Association Charnizay, son passé et la Nouvelle- France [{'work': 'B.', 'year': '1996', 'page': '656'}, {'work': 'B.', 'year': '1997', 'page': '49'}, {'work': 'B.', 'year': '1999', 'page': '704'}]
# 10 Association des Amis de saint François de Paule [{'work': 'B.', 'year': '1994', 'page': '66'}]
# 11 Association des Amis du Patrimoine de Sainte- Maure [{'work': 'B.', 'year': '2000', 'page': '51'}]
# 11 Association des Conservateurs des Antiquités et objets d’art [{'work': 'B.', 'year': '1997', 'page': '62'}]
# 11 Association pour l'étude de l’art religieux [{'work': 'B.', 'year': '1996', 'page': '974'}]
# 11 ASTES (Fabienne), CUPIC (Danica), MANJRA (Houda), DU PASSAGE (Chantal) [{'work': 'B.', 'year': '2000', 'page': '388'}]
# 11 ATHÉE (Girard d’) [{'work': 'B.', 'year': '1999', 'page': '897'}]
# 11 Athée-sur-Cher [{'work': 'B.', 'year': '1996', 'page': '741'}, {'work': 'B.', 'year': '2001', 'page': '49'}, {'work': 'B.', 'year': '1998', 'page': '407'}, {'work': 'B.', 'year': '1998', 'page': '584'}, {'work': 'B.', 'year': '1994', 'page': '208'}, {'work': 'B.', 'year': '1998', 'page': '584'}, {'work': 'B.', 'year': '1997', 'page': '67'}]
# 11 ATHENIUS [{'work': 'M.', 'number': 'LXIII', 'page': '229'}]
# 11 ATHOMAS (Anne-Marie) [{'work': 'B.', 'year': '1995', 'page': '596'}]
# 11 ATTERTON (Harry) [{'work': 'B.', 'year': '1999', 'page': '701'}, {'work': 'B.', 'year': '2003', 'page': '21'}]
# 11 ATTONS [{'work': 'B.', 'year': '2001', 'page': '48'}]
# 11 B.1994, 219 [{'work': 'B.', 'year': '1994', 'page': '219'}]
# 11 Aubenage (droit d”) [{'work': 'B.', 'year': '2000', 'page': '219'}]
# 11 Auberges de l'Image, B.1995, 516 [{'work': 'B.', 'year': '1995', 'page': '516'}]
# 11 AUBERT (Antoine) [{'work': 'B.', 'year': '2602', 'page': '110'}]
# 11 AUBERT (François), architecte [{'work': 'B.', 'year': '1997', 'page': '266'}]
# 11 AUBERT (Jean-Pierre) -Public. :" La ville d’Am- boise au XV°s (1421-1498), B.1995, 594 [{'work': 'B.', 'year': '1995', 'page': '594'}]
# 11 AUBERT DU PETIT-THOUARS (Georges) [{'work': 'B.', 'year': '1998', 'page': '502'}]
# 11 Aubigné-Racan [{'work': 'B.', 'year': '1997', 'page': '136'}, {'work': 'B.', 'year': '1997', 'page': '52'}]
# 11 Aubigny [{'work': 'B.', 'year': '1997', 'page': '224'}]
# 11 AUBINEAU (Pascale), RENAUD (Emmanuelle), JOUANNET (Catherine) et SIRON (Anne) [{'work': 'B.', 'year': '1996', 'page': '979'}]
# 11 AUBINEAU (Pierre) [{'work': 'M.', 'number': 'LXII', 'page': '122'}]
# 11 AUBOIN (Christophe) [{'work': 'B.', 'year': '1998', 'page': '666'}]
# 11 AUBOUIN (Michel), BOUTET (Gérard), BRIAIS (Bernard) et GAUMONT (Roger) [{'work': 'B.', 'year': '1997', 'page': '349'}]
# 11 AUBRY (Denis-Louis), inspecteur général des manufactures, décédé en 1781; époux de Louise-Françoise de Saint-Martin [{'work': 'B.', 'year': '1994', 'page': '203'}, {'work': 'B.', 'year': '1994', 'page': '208'}]
# 11 AUBRY (Jacques-Amable) [{'work': 'B.', 'year': '1995', 'page': '464'}]
# 11 AUBRY (Jean) [{'work': 'B.', 'year': '1995', 'page': '503'}]
# 11 Aubry (Marc) [{'work': 'B.', 'year': '1999', 'page': '689'}, {'work': 'B.', 'year': '2003', 'page': '14'}]
# 11 AUBRY (Thierry) [{'work': 'B.', 'year': '1998', 'page': '661'}, {'work': 'B.', 'year': '1997', 'page': '343'}, {'work': 'B.', 'year': '2001', 'page': '219'}]
# 11 Auclair (Bernard) [{'work': 'B.', 'year': '2002', 'page': '4'}]
# 11 AUCLERC J.C [{'work': 'B.', 'year': '1995', 'page': '349'}]
# 11 AUDART (chanoine) [{'work': 'B.', 'year': '1997', 'page': '289'}]
# 11 AUDEBERT (dom) [{'work': 'B.', 'year': '2000', 'page': '256'}]
# 11 AUDEBERT [{'work': 'B.', 'year': '2002', 'page': '195'}]
# 11 AUDIBERT (C) [{'work': 'B.', 'year': '2000', 'page': '383'}]
# 11 AUDIFFREDY (Caroline d’) [{'work': 'B.', 'year': '1997', 'page': '240'}]
# 11 Audin (Pierre) [{'work': 'B.', 'year': '1995', 'page': '340'}, {'work': 'B.', 'year': '2002', 'page': '26'}]
# 11 2003, 14 [{'work': 'B.', 'year': '1994', 'page': '321'}, {'work': 'B.', 'year': '1995', 'page': '593'}, {'work': 'B.', 'year': '1996', 'page': '973'}, {'work': 'B.', 'year': '1997', 'page': '343'}, {'work': 'B.', 'year': '1996', 'page': '892'}, {'work': 'B.', 'year': '2001', 'page': '10'}, {'work': 'B.', 'year': '2002', 'page': '5'}, {'work': 'B.', 'year': '2001', 'page': '219'}, {'work': 'B.', 'year': '1998', 'page': '376'}, {'work': 'B.', 'year': '2002', 'page': '11'}, {'work': 'B.', 'year': '1999', 'page': '851'}]
# 11 Conf. : "La colonie agricole de Mettray" B.1999, 702 [{'work': 'B.', 'year': '1999', 'page': '702'}, {'work': 'B.', 'year': '1996', 'page': '668'}, {'work': 'B.', 'year': '2002', 'page': '4'}, {'work': 'B.', 'year': '2003', 'page': '22'}, {'work': 'B.', 'year': '1994', 'page': '324'}]
# 12  -9- Révolution : les Montois face à la maladie" B.1997, 347- "A Monts au XVILS: l'équipement des maisons paysannes", B.1996, 976" [{'work': 'B.', 'year': '1997', 'page': '347'}, {'work': 'B.', 'year': '1996', 'page': '976'}, {'work': 'B.', 'year': '1996', 'page': '977'}, {'work': 'B.', 'year': '2001', 'page': '224'}, {'work': 'B.', 'year': '1994', 'page': '323'}, {'work': 'B.', 'year': '1996', 'page': '667'}, {'work': 'B.', 'year': '2000', 'page': '383'}, {'work': 'B.', 'year': '1994', 'page': '324'}, {'work': 'B.', 'year': '1999', 'page': '1021'}, {'work': 'B.', 'year': '2001', 'page': '223'}, {'work': 'B.', 'year': '1998', 'page': '672'}, {'work': 'B.', 'year': '1996', 'page': '977'}, {'work': 'B.', 'year': '2003', 'page': '235'}, {'work': 'B.', 'year': '1994', 'page': '324'}, {'work': 'B.', 'year': '1995', 'page': '596'}, {'work': 'B.', 'year': '1995', 'page': '594'}, {'work': 'B.', 'year': '1996', 'page': '976'}, {'work': 'B.', 'year': '1997', 'page': '343'}, {'work': 'B.', 'year': '2001', 'page': '221'}, {'work': 'B.', 'year': '1999', 'page': '1025'}, {'work': 'B.', 'year': '2001', 'page': '223'}, {'work': 'B.', 'year': '1994', 'page': '323'}, {'work': 'B.', 'year': '2002', 'page': '2000'}, {'work': 'B.', 'year': '1997', 'page': '350'}, {'work': 'B.', 'year': '1996', 'page': '667'}, {'work': 'B.', 'year': '1994', 'page': '326'}, {'work': 'B.', 'year': '2000', 'page': '385'}, {'work': 'B.', 'year': '2001', 'page': '221'}, {'work': 'B.', 'year': '1995', 'page': '600'}, {'work': 'B.', 'year': '1998', 'page': '672'}, {'work': 'B.', 'year': '2001', 'page': '16'}, {'work': 'B.', 'year': '1994', 'page': '71'}, {'work': 'B.', 'year': '1999', 'page': '1024'}]
# 13  historique de Saché", B.1998, 670 [{'work': 'B.', 'year': '1998', 'page': '670'}, {'work': 'B.', 'year': '2001', 'page': '224'}, {'work': 'B.', 'year': '2002', 'page': '5'}, {'work': 'B.', 'year': '1996', 'page': '667'}, {'work': 'B.', 'year': '2000', 'page': '389'}, {'work': 'B.', 'year': '1994', 'page': '323'}, {'work': 'B.', 'year': '1995', 'page': '594'}, {'work': 'B.', 'year': '2002', 'page': '13'}, {'work': 'B.', 'year': '1997', 'page': '347'}, {'work': 'B.', 'year': '1994', 'page': '322'}, {'work': 'B.', 'year': '2001', 'page': '219'}, {'work': 'B.', 'year': '2003', 'page': '237'}, {'work': 'B.', 'year': '2003', 'page': '233'}, {'work': 'B.', 'year': '2003', 'page': '236'}, {'work': 'B.', 'year': '2003', 'page': '237'}]
# 13 AUDINET (Isabelle) [{'work': 'B.', 'year': '1999', 'page': '1017'}]
# 13 AUDOUIN (Jean) [{'work': 'B.', 'year': '1999', 'page': '1096'}]
# 13 AUDREN (Vincent) [{'work': 'B.', 'year': '1998', 'page': '667'}]
# 13 AUDUBERT(Philippe) [{'work': 'B.', 'year': '1995', 'page': '595'}]
# 13 AUDUC (Alfred)- B.2000, 372 sq AUFFRAIS (André) [{'work': 'B.', 'year': '2000', 'page': '372'}, {'work': 'B.', 'year': '1996', 'page': '970'}, {'work': 'B.', 'year': '2003', 'page': '229'}]
# 13 AUGER (Marcel) [{'work': 'B.', 'year': '2003', 'page': '231'}, {'work': 'B.', 'year': '1996', 'page': '979'}]
# 13 AUGUSTIN DE BOURGUISSON (Casimir d’} [{'work': 'B.', 'year': '1996', 'page': '860'}]
# 13 AUGUSTIN DE BOURGUISSON  (Etienne- Charles d”), époux d'Estelle Huon [{'work': 'B.', 'year': '1996', 'page': '860'}]
# 13 AUGUSTIN DE BOURGUISSON (Pierre-Charles d'}- B.1996, 860 [{'work': 'B.', 'year': '1996', 'page': '860'}]
# 13 Aulnay-de-Saintonge [{'work': 'B.', 'year': '1997', 'page': '59'}]
# 15 -10- AULOT (M.P.} et AUTRES [{'work': 'B.', 'year': '1994', 'page': '324'}]
# 15 AUMOITTE (Joseph), vicaire de Ste-Maure, curé de Ia Chapelle-sur-Loire, B.1995, 574 [{'work': 'B.', 'year': '1995', 'page': '574'}]
# 15 Aurigny [{'work': 'B.', 'year': '2000', 'page': '259'}]
# 15 Aurousseau Paul [{'work': 'B.', 'year': '2002', 'page': '2'}]
# 15 AUSONE [{'work': 'M.', 'number': 'LXI', 'page': '22'}]
# 15 Autoroute Alençon-Tours [{'work': 'B.', 'year': '2000', 'page': '126'}]
# 15 Autrèche [{'work': 'B.', 'year': '1999', 'page': '786'}]
# 15 B.2003, 31 [{'work': 'B.', 'year': '2003', 'page': '31'}, {'work': 'B.', 'year': '2003', 'page': '21'}, {'work': 'B.', 'year': '1997', 'page': '264'}]
# 15 AUTRICHE (Anne d’} [{'work': 'B.', 'year': '1995', 'page': '455'}]
# 15 AUMONT (César d'} [{'work': 'B.', 'year': '2003', 'page': '138'}, {'work': 'B.', 'year': '1994', 'page': '51'}]
# 15 Auvray (Henri-Martin) [{'work': 'B.', 'year': '1994', 'page': '69'}]
# 15 AUXENCE [{'work': 'M.', 'number': 'LXII', 'page': '38'}]
# 15 AUXENTIUS [{'work': 'M.', 'number': 'LXIII', 'page': '249'}]
# 15 Auxerre (Yonne) [{'work': 'M.', 'number': 'LXII', 'page': '69'}]
# 15 Auzouer [{'work': 'B.', 'year': '2001', 'page': '154'}]
# 15 AVANNE (Louis d’} [{'work': 'B.', 'year': '1997', 'page': '201'}]
# 15 AVANNE (Victor d°) [{'work': 'B.', 'year': '1997', 'page': '201'}, {'work': 'M.', 'number': 'LXIL', 'page': '66'}]
# 15 AVICIEN [{'work': 'B.', 'year': '1997', 'page': '101'}]
# 15 AVISSEAU [{'work': 'B.', 'year': '1997', 'page': '58'}, {'work': 'B.', 'year': '2000', 'page': '52'}, {'work': 'B.', 'year': '2001', 'page': '215'}, {'work': 'B.', 'year': '2002', 'page': '12'}, {'work': 'B.', 'year': '2002', 'page': '13'}]
# 15 AVISSEAU (Joseph-Edouard) [{'work': 'B.', 'year': '2002', 'page': '14'}]
# 15 Avoine [{'work': 'B.', 'year': '2001', 'page': '221'}, {'work': 'B.', 'year': '1994', 'page': '62'}]
# 15 Avon-les-Roches [{'work': 'B.', 'year': '2000', 'page': '54'}, {'work': 'B.', 'year': '1999', 'page': '910'}, {'work': 'B.', 'year': '2000', 'page': '54'}]
# 15 Avranches [{'work': 'M.', 'number': 'LXIL', 'page': '66'}]
# 15 AVRANCHES (Henri d’) -B.1999, 898 [{'work': 'B.', 'year': '1999', 'page': '898'}]
# 15 AVRIL (Aïthur) [{'work': 'B.', 'year': '2003', 'page': '230'}, {'work': 'B.', 'year': '2002', 'page': '85'}]
# 16  AYRAULT (François) [{'work': 'B.', 'year': '2001', 'page': '220'}]
# 16 Azay-le-Ferron [{'work': 'B.', 'year': '1997', 'page': '260'}, {'work': 'B.', 'year': '2000', 'page': '214'}]
# 16 1994, 60 [{'work': 'B.', 'year': '2000', 'page': '286'}, {'work': 'B.', 'year': '1998', 'page': '494'}, {'work': 'B.', 'year': '2001', 'page': '84'}, {'work': 'B.', 'year': '1998', 'page': '606'}, {'work': 'B.', 'year': '2001', 'page': '50'}, {'work': 'B.', 'year': '1994', 'page': '53'}, {'work': 'B.', 'year': '2000', 'page': '346'}, {'work': 'B.', 'year': '1994', 'page': '60'}, {'work': 'B.', 'year': '1995', 'page': '555'}, {'work': 'B.', 'year': '1994', 'page': '60'}]
# 16 Lieux-dits : La Folaine, voir Audin: Le Gerfault, voir Ternier [{'work': 'B.', 'year': '2001', 'page': '86'}, {'work': 'B.', 'year': '2001', 'page': '217'}, {'work': 'B.', 'year': '1999', 'page': '696'}, {'work': 'B.', 'year': '2001', 'page': '220'}, {'work': 'B.', 'year': '1999', 'page': '698'}, {'work': 'B.', 'year': '1999', 'page': '680'}, {'work': 'B.', 'year': '1994', 'page': '206'}, {'work': 'B.', 'year': '1994', 'page': '42'}, {'work': 'B.', 'year': '1997', 'page': '67'}, {'work': 'B.', 'year': '1994', 'page': '208'}, {'work': 'B.', 'year': '1997', 'page': '266'}, {'work': 'B.', 'year': '1994', 'page': '218'}, {'work': 'B.', 'year': '1994', 'page': '209'}, {'work': 'B.', 'year': '1998', 'page': '584'}, {'work': 'B.', 'year': '1994', 'page': '208'}, {'work': 'B.', 'year': '1997', 'page': '67'}, {'work': 'B.', 'year': '1994', 'page': '209'}, {'work': 'B.', 'year': '1994', 'page': '218'}, {'work': 'B.', 'year': '1994', 'page': '209'}, {'work': 'B.', 'year': '1994', 'page': '209'}]
# 16 Azay-sur-Indre [{'work': 'B.', 'year': '1996', 'page': '743'}, {'work': 'B.', 'year': '1996', 'page': '921'}]
# 16 B BABELON (Jean-Pierre) [{'work': 'B.', 'year': '2001', 'page': '153'}]
# 16 BABOU (Georges I) [{'work': 'B.', 'year': '2003', 'page': '133'}, {'work': 'B.', 'year': '2003', 'page': '133'}]
# 17 li BABOU (Isabeile), veuve de François d’Escou- bleau, B.2003, 133 [{'work': 'B.', 'year': '2003', 'page': '133'}, {'work': 'B.', 'year': '1994', 'page': '226'}]
# 17 BABOU (Jean) [{'work': 'B.', 'year': '2003', 'page': '132'}, {'work': 'B.', 'year': '1994', 'page': '222'}]
# 17 BACHELIER (Dominique) [{'work': 'B.', 'year': '2000', 'page': '354'}]
# 17 BACHELIER (Thérèse) [{'work': 'B.', 'year': '1997', 'page': '315'}]
# 17 BACHELLA (Nicole) [{'work': 'B.', 'year': '1999', 'page': '1025'}]
# 17 BACHRACH (Bernard) [{'work': 'B.', 'year': '2000', 'page': '383'}]
# 17 BACOT (famille) [{'work': 'B.', 'year': '1997', 'page': '265'}, {'work': 'B.', 'year': '1994', 'page': '218'}]
# 17 Bacot (Jean-Marie) [{'work': 'B.', 'year': '2002', 'page': '4'}, {'work': 'B.', 'year': '2002', 'page': '165'}]
# 17 Badier (Jean-François) [{'work': 'B.', 'year': '2000', 'page': '53'}]
# 17 BADOU (Mme) [{'work': 'B.', 'year': '1995', 'page': '471'}]
# 17 BAGARRIE (Paul) [{'work': 'B.', 'year': '1996', 'page': '971'}]
# 17 Baglin (Robert) [{'work': 'B.', 'year': '1996', 'page': '672'}]
# 17 BAÏDULUS [{'work': 'M.', 'number': 'LXII', 'page': '46'}]
# 17 Baigne [{'work': 'B.', 'year': '2002', 'page': '55'}]
# 17 Baignon [{'work': 'B.', 'year': '1996', 'page': '675'}]
# 17 Baignoux [{'work': 'B.', 'year': '1996', 'page': '675'}]
# 17 Baïillard (Geneviève) [{'work': 'B.', 'year': '1994', 'page': '43'}]
# 17 BAILLARGÉ (Alphonse-Jules), architecte, B.1997 194 ; B.2001, 155 [{'work': 'B.', 'year': '2001', 'page': '155'}]
# 17 BAITLLARGER (Daniel), meunier [{'work': 'B.', 'year': '1997', 'page': '230'}]
# 17 BAILLARGER (Eulalie) [{'work': 'B.', 'year': '1997', 'page': '230'}]
# 17 BAILLARGER (François) [{'work': 'B.', 'year': '1995', 'page': '511'}]
# 17 BAILLARGER (Jules-Gabriel ), médecin [{'work': 'B.', 'year': '1995', 'page': '511'}, {'work': 'B.', 'year': '1997', 'page': '230'}, {'work': 'B.', 'year': '2000', 'page': '343'}]
# 17 BAILLARGER (Marie-Agathe) [{'work': 'B.', 'year': '1997', 'page': '230'}]
# 17 Baiïllaud (Denis) [{'work': 'B.', 'year': '1999', 'page': '689'}]
# 17 Bailleul Raymond [{'work': 'B.', 'year': '1999', 'page': '697'}]
# 17 BAILLOU (Roger) [{'work': 'B.', 'year': '2003', 'page': '225'}]
# 17 Balatedinis [{'work': 'M.', 'number': 'LXIV', 'page': '64'}]
# 17 BALESCHOUX (Gatien), fermier de l’abbaye de Cormery, B.1995, 538. [{'work': 'B.', 'year': '1995', 'page': '538'}]
# 19 Balesmes [{'work': 'B.', 'year': '1998', 'page': '421'}, {'work': 'B.', 'year': '1999', 'page': '698'}, {'work': 'B.', 'year': '1996', 'page': '809'}, {'work': 'B.', 'year': '1994', 'page': '198'}, {'work': 'B.', 'year': '1997', 'page': '254'}, {'work': 'B.', 'year': '1999', 'page': '609'}, {'work': 'B.', 'year': '1999', 'page': '698'}, {'work': 'B.', 'year': '1994', 'page': '60'}, {'work': 'B.', 'year': '1994', 'page': '244'}, {'work': 'B.', 'year': '1999', 'page': '699'}, {'work': 'B.', 'year': '1995', 'page': '452'}, {'work': 'M.', 'number': 'LXIV', 'page': '64'}, {'work': 'M.', 'number': 'LXIV', 'page': '78'}, {'work': 'M.', 'number': 'LXIV', 'page': '64'}, {'work': 'M.', 'number': 'LXIV', 'page': '132'}]
# 19 Lieux-dits : Bois-Renault, exposition photographique, B.2001, 7: voir aussi Vieira [{'work': 'B.', 'year': '2001', 'page': '7'}, {'work': 'B.', 'year': '1997', 'page': '265'}, {'work': 'B.', 'year': '1998', 'page': '651'}, {'work': 'B.', 'year': '2000', 'page': '401'}, {'work': 'B.', 'year': '2001', 'page': '106'}, {'work': 'B.', 'year': '1997', 'page': '344'}, {'work': 'B.', 'year': '1999', 'page': '699'}, {'work': 'B.', 'year': '1999', 'page': '700'}, {'work': 'B.', 'year': '1999', 'page': '699'}, {'work': 'B.', 'year': '1999', 'page': '698'}]
# 19 Ballatetone [{'work': 'M.', 'number': 'LXIV', 'page': '132'}]
# 19 BALLON (Marcel) [{'work': 'B.', 'year': '1997', 'page': '349'}, {'work': 'B.', 'year': '1999', 'page': '1003'}, {'work': 'B.', 'year': '2000', 'page': '370'}]
# 19 BALUE (Jean) [{'work': 'B.', 'year': '2001', 'page': '7'}]
# 19 BALUZE [{'work': 'B.', 'year': '2000', 'page': '253'}]
# 19 2003, 22 [{'work': 'B.', 'year': '2001', 'page': '218'}, {'work': 'B.', 'year': '2001', 'page': '214'}, {'work': 'B.', 'year': '1996', 'page': '669'}]
# 19 BALZAC (Bernard-François) [{'work': 'B.', 'year': '1998', 'page': '599'}]
# 19 BARAIS (Pierre), expert [{'work': 'B.', 'year': '1995', 'page': '563'}, {'work': 'B.', 'year': '1998', 'page': '665'}]
# 19 Baranton (Thérèse) [{'work': 'B.', 'year': '1995', 'page': '348'}]
# 19 BARAUDIN (Marie-Archange de) [{'work': 'B.', 'year': '1995', 'page': '476'}]
# 19 Barba (André) [{'work': 'B.', 'year': '1998', 'page': '379'}, {'work': 'B.', 'year': '2002', 'page': '11'}]
# 19 Barbier (Jean-Michel) [{'work': 'B.', 'year': '1996', 'page': '648'}]
# 19 BARBIER-DUFAYS de SAINT-FELIX [{'work': 'B.', 'year': '1995', 'page': '544'}, {'work': 'B.', 'year': '1995', 'page': '544'}]
# 20 -12- BARBO (dom Ludovico) [{'work': 'M.', 'number': 'LXIL', 'page': '54'}]
# 20 BARBOT (Jacques) [{'work': 'B.', 'year': '1996', 'page': '946'}]
# 20 BARBOTEAU, sergent du  Châtelleraudais, B.1999, 692 [{'work': 'B.', 'year': '1999', 'page': '692'}]
# 20 BARBOTIN (Isabelle) [{'work': 'B.', 'year': '1999', 'page': '1021'}]
# 20 BARDET (Claude) [{'work': 'B.', 'year': '2003', 'page': '236'}]
# 20 Bardisa (Marie) [{'work': 'B.', 'year': '1996', 'page': '648'}, {'work': 'B.', 'year': '1994', 'page': '322'}]
# 20 Architecture et peuplement de la basse vallée de la Claise jusqu'au XVI°s", B.1996, 978 [{'work': 'B.', 'year': '1996', 'page': '978'}]
# 20 BARDOULEAU (Anne-Catherine) [{'work': 'B.', 'year': '1996', 'page': '922'}]
# 20 BARGUIN Victor, sgr de Montifray, B.1994, 267 [{'work': 'B.', 'year': '1994', 'page': '267'}]
# 20 BARJOT [{'work': 'B.', 'year': '1998', 'page': '506'}]
# 20 BARJOT (Claude) [{'work': 'B.', 'year': '1998', 'page': '502'}]
# 20 BARIOT (Denise) [{'work': 'B.', 'year': '1998', 'page': '505'}]
# 20 BARLOU (Michelle) [{'work': 'B.', 'year': '1994', 'page': '324'}]
# 20 BARNARD (Georges) [{'work': 'B.', 'year': '2001', 'page': '205'}]
# 20 BARNSBY (David Robert), botaniste [{'work': 'B.', 'year': '1994', 'page': '290'}, {'work': 'B.', 'year': '1996', 'page': '933'}]
# 20 BAROIR (veuve) [{'work': 'B.', 'year': '1995', 'page': '561'}]
# 20 BARON (Gisèle), boulangère à Chenu [{'work': 'B.', 'year': '2000', 'page': '372'}]
# 20 BARON (Marcel) [{'work': 'B.', 'year': '2003', 'page': '225'}]
# 20 BARRAL (Mgr de) [{'work': 'B.', 'year': '1995', 'page': '462'}, {'work': 'B.', 'year': '1997', 'page': '193'}]
# 20 BARRAT (Madeleine-Sophie) [{'work': 'B.', 'year': '1997', 'page': '294'}]
# 20 BARRÉ (Nicolas) [{'work': 'B.', 'year': '2001', 'page': '113'}]
# 20 BARRÉ DE SAINT-VENANT (comtesse) [{'work': 'B.', 'year': '2001', 'page': '153'}]
# 20 BARRION [{'work': 'B.', 'year': '2001', 'page': '159'}]
# 20 Barrou [{'work': 'B.', 'year': '1996', 'page': '807'}]
# 20 LXIV, 84 [{'work': 'B.', 'year': '2000', 'page': '389'}, {'work': 'M.', 'number': 'LXIV', 'page': '78'}]
# 20 BARTHÉLEMY [{'work': 'B.', 'year': '1995', 'page': '452'}, {'work': 'B.', 'year': '1999', 'page': '859'}]
# 20 BARTHÉLEMY DE VENDÔME, archevêque de Tours [{'work': 'B.', 'year': '2000', 'page': '227'}]
# 20 BARTHÉLEMY (D) [{'work': 'B.', 'year': '1997', 'page': '344'}]
# 21 des châteaux dans la Touraine du XEs, " B.1997, 345 [{'work': 'B.', 'year': '1997', 'page': '345'}, {'work': 'B.', 'year': '1997', 'page': '344'}]
# 21 BARTHÉLEMY (Florence) [{'work': 'B.', 'year': '1994', 'page': '75'}, {'work': 'B.', 'year': '2000', 'page': '382'}]
# 21 Barthélemy (Serge) [{'work': 'B.', 'year': '1997', 'page': '40'}]
# 21 BARTHES [{'work': 'B.', 'year': '2001', 'page': '159'}]
# 21 BARTILLAT (lieutenant de) [{'work': 'B.', 'year': '1996', 'page': '965'}]
# 21 BAS (Catherine) [{'work': 'B.', 'year': '1997', 'page': '350'}, {'work': 'B.', 'year': '2000', 'page': '389'}, {'work': 'B.', 'year': '1998', 'page': '672'}]
# 21 Courçay et de Reignac", "B.1998, 672 [{'work': 'B.', 'year': '1998', 'page': '672'}, {'work': 'B.', 'year': '1999', 'page': '350'}, {'work': 'B.', 'year': '1994', 'page': '323'}, {'work': 'B.', 'year': '1995', 'page': '596'}]
# 21 BAS (Emmanuel) [{'work': 'B.', 'year': '1994', 'page': '324'}]
# 21 BASSEREAU [{'work': 'B.', 'year': '2000', 'page': '45'}]
# 21 BASSEREAU (CM) [{'work': 'B.', 'year': '2000', 'page': '383'}]
# 21 Bassin [{'work': 'B.', 'year': '2002', 'page': '51'}]
# 21 BASSOMPIERRE [{'work': 'B.', 'year': '2004', 'page': '135'}]
# 21 BASTARD (Henri-Amoureux) [{'work': 'B.', 'year': '1995', 'page': '544'}]
# 21 BASTARD (Eaurent) et JAM (Hubert) [{'work': 'B.', 'year': '2000', 'page': '386'}]
# 21 BASTIEN (adjudant-chef) [{'work': 'B.', 'year': '1996', 'page': '957'}]
# 21 BASTIEN (G.) [{'work': 'B.', 'year': '1999', 'page': '1015'}]
# 21 BASTIEN (Gilbert), BOURHIS (Jean-Roger), BRIARD (Jacques) [{'work': 'B.', 'year': '1995', 'page': '593'}]
# 21 BASTIEN (Gilbert), MASFRAND (J) [{'work': 'B.', 'year': '2003', 'page': '233'}, {'work': 'B.', 'year': '1997', 'page': '284'}]
# 21 BATAILLE (Paul), architecte, B.1997, 284; B.2001, 217 [{'work': 'B.', 'year': '1997', 'page': '284'}, {'work': 'B.', 'year': '2001', 'page': '217'}]
# 21 BATAILLE (S.} [{'work': 'B.', 'year': '2002', 'page': '200'}]
# 21 Battle (Angleterre) [{'work': 'M.', 'number': 'LXI', 'page': '51'}]
# 22 -13- BAUBE (dom) [{'work': 'B.', 'year': '1995', 'page': '539'}, {'work': 'B.', 'year': '1996', 'page': '820'}]
# 22 BAUCHANT (famille) [{'work': 'B.', 'year': '1996', 'page': '916'}]
# 22 Bauché [{'work': 'B.', 'year': '2000', 'page': '218'}]
# 22 BAUDET-BERTHELOT [{'work': 'B.', 'year': '2000', 'page': '218'}]
# 22 BAUDICHON (Jean) [{'work': 'B.', 'year': '2000', 'page': '326'}]
# 22 BAUDICHON (René), graveur sur médaille, B.1995, 573 [{'work': 'B.', 'year': '1995', 'page': '573'}]
# 22 BAUDOIN (Marie-Marguerite) [{'work': 'B.', 'year': '1999', 'page': '1021'}]
# 22 BAUDOT (François-Nicolas) [{'work': 'B.', 'year': '2002', 'page': '40'}]
# 22 BAUDRICOURT (Jean) [{'work': 'B.', 'year': '1995', 'page': '453'}]
# 22 BAUER (Johan) [{'work': 'B.', 'year': '2001', 'page': '221'}]
# 23 Baugé [{'work': 'B.', 'year': '1997', 'page': '171'}]
# 23 BAUGER, curé de Villeoin-Coulangé, résistant, B.1994, 208 [{'work': 'B.', 'year': '1994', 'page': '208'}]
# 23 Public. :" Le corps de ville de Tours, de la réforme de Lavardy à la Révolution", B.2001, 221 [{'work': 'B.', 'year': '2001', 'page': '221'}]
# 23 BAUTRU de VAUBRUN (Nicolas) [{'work': 'B.', 'year': '2000', 'page': '254'}]
# 23 BAYARD (Antoine), trésorier des finances du Languedoc, B.1995, 450 [{'work': 'B.', 'year': '1995', 'page': '450'}]
# 23 BÉAL (Claude) [{'work': 'B.', 'year': '2000', 'page': '389'}]
# 23 BEAU (Stéphane) [{'work': 'B.', 'year': '2001', 'page': '222'}]
# 23 BEAUBRUN (Charles) [{'work': 'B.', 'year': '1999', 'page': '1033'}, {'work': 'B.', 'year': '2000', 'page': '394'}, {'work': 'B.', 'year': '2001', 'page': '213'}]
# 23 BEAUCHAMP (famille de) [{'work': 'B.', 'year': '1994', 'page': '59'}]
# 23 Beauchet-Filleau (Henri) [{'work': 'B.', 'year': '2003', 'page': '2004'}, {'work': 'B.', 'year': '1996', 'page': '951'}]
# 23 BEAUDOUIN (Joseph), exécuté, B.1995, 560 [{'work': 'B.', 'year': '1995', 'page': '560'}]
# 23 Beaufort-en-Vallée [{'work': 'B.', 'year': '1995', 'page': '490'}]
# 23 Beaugency [{'work': 'B.', 'year': '1999', 'page': '687'}]
# 23 BEAUGÉ, serrurier à Savonnières [{'work': 'B.', 'year': '1994', 'page': '245'}]
# 23 BEAUJEU (Anne de) [{'work': 'B.', 'year': '1995', 'page': '450'}]
# 25 BEAUJEU (Jean) [{'work': 'M.', 'number': 'X', 'page': '48'}]
# 25 BEAULIEU (Michèle) et BEYER (Victor) [{'work': 'B.', 'year': '2000', 'page': '383'}]
# 25 Beaulieu-lès-Loches [{'work': 'B.', 'year': '1998', 'page': '373'}, {'work': 'B.', 'year': '1995', 'page': '359'}]
# 25 BEAUMIER (Béatrice) [{'work': 'B.', 'year': '1995', 'page': '500'}]
# 25 BEAUMONT (abbé de) [{'work': 'B.', 'year': '1997', 'page': '194'}]
# 25 BEAUMONT (Charles de) [{'work': 'B.', 'year': '2001', 'page': '109'}]
# 25 Beaumont-en-Véron [{'work': 'B.', 'year': '1994', 'page': '63'}, {'work': 'B.', 'year': '1994', 'page': '62'}, {'work': 'B.', 'year': '2000', 'page': '360'}, {'work': 'B.', 'year': '1994', 'page': '62'}, {'work': 'B.', 'year': '1994', 'page': '63'}, {'work': 'M.', 'number': 'XI', 'page': '57'}, {'work': 'M.', 'number': 'XI', 'page': '67'}]
# 25 XL, 63, ill [{'work': 'B.', 'year': '1994', 'page': '323'}, {'work': 'B.', 'year': '1999', 'page': '952'}, {'work': 'B.', 'year': '1995', 'page': '335'}, {'work': 'B.', 'year': '1994', 'page': '322'}, {'work': 'M.', 'number': 'XI', 'page': '57'}, {'work': 'M.', 'number': 'XI', 'page': '55'}, {'work': 'M.', 'number': 'XI', 'page': '58'}, {'work': 'M.', 'number': 'XI', 'page': '62'}, {'work': 'M.', 'number': 'LXIII', 'page': '165'}]
# 25 BEAUNE (famille) [{'work': 'B.', 'year': '1996', 'page': '880'}, {'work': 'B.', 'year': '1997', 'page': '345'}]
# 25 BEAUNE (Fiorimond) [{'work': 'B.', 'year': '1996', 'page': '867'}]
# 25 BEAUNE (Guillaume de), B.1996, 866 [{'work': 'B.', 'year': '1996', 'page': '866'}]
# 25 BEAUNE (Jacques de) [{'work': 'B.', 'year': '1996', 'page': '866'}, {'work': 'B.', 'year': '1999', 'page': '699'}, {'work': 'B.', 'year': '2001', 'page': '106'}, {'work': 'M.', 'number': 'X', 'page': '47'}]
# 25 BEAURNE (Jean de) [{'work': 'B.', 'year': '2001', 'page': '106'}]
# 25 BEAUNE (Marie de) [{'work': 'B.', 'year': '1996', 'page': '866'}]
# 25 BEAUNE (Renaud de) [{'work': 'B.', 'year': '1996', 'page': '866'}]
# 25 BEAUNEVEU (André) [{'work': 'B.', 'year': '2001', 'page': '207'}]
# 26 -14- Beaupréau (Maine-et-Loire) [{'work': 'M.', 'number': 'LXII', 'page': '176'}]
# 26 Beauvais [{'work': 'B.', 'year': '1996', 'page': '921'}]
# 26 BEAUVAIS (Raoul) [{'work': 'B.', 'year': '1994', 'page': '206'}]
# 26 BEAUVAL [{'work': 'B.', 'year': '2003', 'page': '223'}, {'work': 'B.', 'year': '2000', 'page': '278'}]
# 26 BEAUVAU (Jacques de) [{'work': 'B.', 'year': '2000', 'page': '278'}]
# 26 BEAUVILLIERS (François de) [{'work': 'B.', 'year': '2003', 'page': '138'}, {'work': 'B.', 'year': '2001', 'page': '221'}]
# 26 BECHE (Marie) [{'work': 'B.', 'year': '2000', 'page': '65'}, {'work': 'B.', 'year': '2000', 'page': '382'}]
# 26 BECKET (Thomas) [{'work': 'M.', 'number': 'LXII', 'page': '129'}]
# 26 BECQUART (Marc) [{'work': 'B.', 'year': '1996', 'page': '946'}]
# 26 BEDAT (Isabelle) [{'work': 'B.', 'year': '1999', 'page': '1016'}, {'work': 'B.', 'year': '2001', 'page': '15'}]
# 26 Bedel (Gérard) [{'work': 'B.', 'year': '1995', 'page': '346'}, {'work': 'B.', 'year': '1996', 'page': '684'}, {'work': 'B.', 'year': '2002', 'page': '51'}]
# 26 BEDON (Robert) [{'work': 'B.', 'year': '2000', 'page': '83'}, {'work': 'B.', 'year': '2002', 'page': '196'}]
# 26 Begards (colonel) [{'work': 'B.', 'year': '1995', 'page': '351'}]
# 26 BEGNICOURT (Jacques) [{'work': 'B.', 'year': '2001', 'page': '1'}, {'work': 'M.', 'number': 'X', 'page': '21'}]
# 26 BEGUIN [{'work': 'B.', 'year': '1997', 'page': '291'}]
# 26 BELBENOIT (V), LORANS (E), FRANCOIS (S) [{'work': 'B.', 'year': '1999', 'page': '1016'}]
# 26 Belin (Michel) [{'work': 'B.', 'year': '1994', 'page': '41'}]
# 26 BELLANGER (Jeannine) [{'work': 'B.', 'year': '1997', 'page': '303'}]
# 26 BELLANGER (Robert), B.1997, 303 sq [{'work': 'B.', 'year': '1997', 'page': '303'}]
# 26 BELLANGER (Stanislas) [{'work': 'B.', 'year': '1999', 'page': '1024'}]
# 26 BELLEFOREST (François de) [{'work': 'B.', 'year': '2001', 'page': '119'}]
# 26 BELLEMANIÉRE (Guillaume) [{'work': 'B.', 'year': '1995', 'page': '548'}]
# 26 Belleroy [{'work': 'M.', 'number': 'LXII', 'page': '169'}]
# 26 Bellet (André) [{'work': 'B.', 'year': '1996', 'page': '652'}]
# 26 BELLIARD (Marguerite) [{'work': 'B.', 'year': '1996', 'page': '866'}]
# 26 BELOT (Jacques), lieutenant général au bailliage de Blois, épouse Anne Laillier [{'work': 'B.', 'year': '1994', 'page': '208'}]
# 26 BELOT (Jacques-Florent), fils de Jacques [{'work': 'B.', 'year': '1994', 'page': '208'}]
# 26 Benaias [{'work': 'M.', 'number': 'LXIV', 'page': '133'}]
# 27  Benais [{'work': 'B.', 'year': '1999', 'page': '758'}, {'work': 'B.', 'year': '1997', 'page': '255'}]
# 27 LXIV, 133 [{'work': 'B.', 'year': '1999', 'page': '746'}, {'work': 'B.', 'year': '1998', 'page': '604'}, {'work': 'B.', 'year': '1997', 'page': '344'}, {'work': 'B.', 'year': '1997', 'page': '344'}, {'work': 'M.', 'number': 'LXIV', 'page': '10'}, {'work': 'M.', 'number': 'LXIV', 'page': '10'}, {'work': 'M.', 'number': 'LXIL', 'page': '55'}]
# 27 BENECH (Jean) [{'work': 'B.', 'year': '1997', 'page': '303'}]
# 27 BENEDICTI (Louis) [{'work': 'B.', 'year': '1995', 'page': '489'}]
# 27 BENOIST (Jean) [{'work': 'B.', 'year': '2002', 'page': '5'}]
# 27 BENOIST DE LA GRANDIÈRE (Louis), maire de Tours [{'work': 'B.', 'year': '1995', 'page': '493'}, {'work': 'B.', 'year': '1998', 'page': '386'}]
# 27 BENOIST (Robert) [{'work': 'B.', 'year': '2000', 'page': '374'}]
# 27 BENOIST D’AZY (Pierre) [{'work': 'B.', 'year': '2002', 'page': '167'}]
# 27 Benoît (Anne-Marie) [{'work': 'B.', 'year': '1977', 'page': '69'}]
# 27 BENOIÏT-CASTELEI (dom Georges) [{'work': 'B.', 'year': '1996', 'page': '821'}]
# 27 BENOIT DU REY (Mme) [{'work': 'B.', 'year': '2001', 'page': '14'}]
# 27 BENOIT DE REY (A.) [{'work': 'B.', 'year': '2001', 'page': '99'}]
# 27 BENOIT DU REY (Félix) [{'work': 'B.', 'year': '2001', 'page': '109'}]
# 27 Bequet (Jacques) [{'work': 'B.', 'year': '2001', 'page': '12'}]
# 27 BÉRANGER (Isaac), marchand de chevaux, B.1995, 542 sq [{'work': 'B.', 'year': '1995', 'page': '542'}]
# 27 BÉRANGER (Alfred), époux de Marie Guillaume [{'work': 'B.', 'year': '1994', 'page': '206'}]
# 27 BÉRANGER (Anne-Marie-Emilie-Charlotte), fille d'Alfred, épouse Gaston-Marie-Adolphe Le Provost de Launay [{'work': 'B.', 'year': '1994', 'page': '219'}]
# 27 Bérard (Louis) [{'work': 'B.', 'year': '2000', 'page': '56'}]
# 27 BÉRART (Pierre) [{'work': 'B.', 'year': '2000', 'page': '171'}]
# 27 BÉRAUD (Françoise) [{'work': 'B.', 'year': '2000', 'page': '346'}]
# 27 Bérault Marcel) [{'work': 'B.', 'year': '1995', 'page': '347'}]
# 27 BEREL (Jean-François) [{'work': 'B.', 'year': '1994', 'page': '324'}]
# 27 BERGERON (Pierre) [{'work': 'M.', 'number': 'X', 'page': '16'}]
# 27 BERGERON DE LA GOUPILLÈRE (Antoine) [{'work': 'B.', 'year': '1995', 'page': '518'}]
# 27 BERLAND (Léon) [{'work': 'B.', 'year': '2002', 'page': '169'}]
# 27 BERLAND (Sylvain) [{'work': 'B.', 'year': '2002', 'page': '199'}]
# 27 BERLUCHON (Laurence) [{'work': 'B.', 'year': '1998', 'page': '655'}]
# 28  -15- BERNACHOT (général) [{'work': 'B.', 'year': '1995', 'page': '353'}]
# 28 BERNAGE (Georges) [{'work': 'B.', 'year': '2001', 'page': '220'}]
# 28 BERNARD), abbé de Saint-Julien [{'work': 'B.', 'year': '1999', 'page': '866'}]
# 28 BERNARD (Alfred), résistant, B. 1994, 312; B.2001, 184; B.2003, 224 [{'work': 'B.', 'year': '1994', 'page': '312'}, {'work': 'B.', 'year': '2001', 'page': '184'}, {'work': 'B.', 'year': '2003', 'page': '224'}]
# 28 BERNARD (Etienne) [{'work': 'B.', 'year': '1999', 'page': '999'}]
# 28 BERNARD (Gui de) [{'work': 'B.', 'year': '2001', 'page': '71'}]
# 28 BERNARD (Jean de) [{'work': 'B.', 'year': '2001', 'page': '71'}, {'work': 'B.', 'year': '2002', 'page': '95'}]
# 28 Bernard (Jean) [{'work': 'B.', 'year': '1998', 'page': '374'}, {'work': 'B.', 'year': '1999', 'page': '981'}, {'work': 'B.', 'year': '1995', 'page': '467'}, {'work': 'B.', 'year': '1998', 'page': '380'}, {'work': 'B.', 'year': '2002', 'page': '14'}, {'work': 'B.', 'year': '1999', 'page': '1016'}, {'work': 'B.', 'year': '1997', 'page': '349'}, {'work': 'B.', 'year': '1998', 'page': '670'}, {'work': 'B.', 'year': '1997', 'page': '347'}, {'work': 'B.', 'year': '1999', 'page': '1019'}, {'work': 'B.', 'year': '1994', 'page': '322'}, {'work': 'B.', 'year': '1996', 'page': '652'}, {'work': 'B.', 'year': '2000', 'page': '60'}]
# 28 BERNARD (Alfred) [{'work': 'B.', 'year': '2003', 'page': '225'}]
# 28 BERNARD (5) Public : "Etude paléoenviron- nementale de la vallée du Lane, du Néolithique au Moyen-Age", B.2000, 384 [{'work': 'B.', 'year': '2000', 'page': '384'}]
# 28 BERNARD (Jean) [{'work': 'B.', 'year': '2003', 'page': '234'}, {'work': 'B.', 'year': '1995', 'page': '596'}]
# 28 Bernard (Michel) [{'work': 'B.', 'year': '1996', 'page': '652'}]
# 28 BERNARDI (Maxime) [{'work': 'B.', 'year': '2001', 'page': '223'}]
# 28 BERNET (Anne) [{'work': 'B.', 'year': '1997', 'page': '345'}]
# 28 BERNON (abbé) [{'work': 'B.', 'year': '1995', 'page': '408'}]
# 28 BERNUY (Guillaume de) [{'work': 'B.', 'year': '1994', 'page': '267'}]
# 28 BERRUYER (Philippe), archidiacre de Tours [{'work': 'B.', 'year': '1995', 'page': '426'}]
# 28 Berry [{'work': 'B.', 'year': '2000', 'page': '209'}, {'work': 'B.', 'year': '1995', 'page': '416'}]
# 29 BERTHAULT [{'work': 'B.', 'year': '2003', 'page': '222'}, {'work': 'B.', 'year': '1995', 'page': '539'}]
# 29 BERTHELOT (Gilles) [{'work': 'B.', 'year': '2001', 'page': '106'}]
# 29 BERTHELOT (Pierre I), abbé de Cormery, B.1994, 121 ; B.2000, 256 [{'work': 'B.', 'year': '1994', 'page': '121'}, {'work': 'B.', 'year': '2000', 'page': '256'}]
# 29 BERTHELOT-LOPIN [{'work': 'B.', 'year': '2002', 'page': '78'}]
# 29 Berthenay- Graffiti, B.1999, 917- Histoire, B [{'work': 'B.', 'year': '1999', 'page': '917'}]
# 29 2001, 49 [{'work': 'B.', 'year': '2000', 'page': '317'}]
# 29 BERTHET DE LA CLUE [{'work': 'B.', 'year': '2000', 'page': '255'}]
# 29 BERTHIER [{'work': 'B.', 'year': '2002', 'page': '196'}]
# 29 BERVAL [{'work': 'B.', 'year': '2003', 'page': '222'}]
# 29 BERTIN, lieutenant général de police à Paris, B.1994, 253 [{'work': 'B.', 'year': '1994', 'page': '253'}]
# 29 BERTIN (Nathalie) [{'work': 'B.', 'year': '1998', 'page': '667'}]
# 29 BERTOT (Jacques) [{'work': 'B.', 'year': '1995', 'page': '482'}]
# 29 BERTRAND (Gabriel), B.1994, 291sq [{'work': 'B.', 'year': '1994', 'page': '291'}]
# 29 BERTRAND (Paul) [{'work': 'B.', 'year': '1997', 'page': '308'}]
# 29 BESNARD, garde-champêtre à Ligueil [{'work': 'B.', 'year': '1999', 'page': '995'}]
# 29 BESNARD (Marie-Christine) et MERIGARD (Karine) [{'work': 'B.', 'year': '1998', 'page': '667'}]
# 29 BESNIER (Père) [{'work': 'B.', 'year': '1995', 'page': '498'}]
# 29 BESNOUARD (Guillaume), maître des oeuvres de maçonnerie de la ville de Tours en 1508, B.1994, 197 [{'work': 'B.', 'year': '1994', 'page': '197'}, {'work': 'M.', 'number': 'X', 'page': '90'}]
# 29 Bessé [{'work': 'B.', 'year': '1996', 'page': '668'}]
# 29 Bessé-sur-Braye [{'work': 'B.', 'year': '1997', 'page': '267'}]
# 29 Bessière (Marie-Louise) [{'work': 'B.', 'year': '1994', 'page': '67'}]
# 29 BESSON (C) [{'work': 'B.', 'year': '1995', 'page': '596'}]
# 29 BÉTHUNE-SULLY (Henri de) [{'work': 'B.', 'year': '2000', 'page': '60'}, {'work': 'B.', 'year': '2000', 'page': '254'}]
# 29 BÉTHUNE (Jean-Baptiste) [{'work': 'B.', 'year': '1997', 'page': '109'}]
# 29 Betz-le-Château [{'work': 'B.', 'year': '1998', 'page': '566'}]
# 29 Beugnon [{'work': 'B.', 'year': '1996', 'page': '676'}]
# 29 BEUGNON (lean), sr de la Clarté [{'work': 'M.', 'number': 'X', 'page': '48'}, {'work': 'M.', 'number': 'X', 'page': '49'}]
# ...
# 258 VESTIER (Archimède-François) [{'work': 'B.', 'year': '1998', 'page': '602'}]
# 259  VESTIER (Nicolas-Jacques-Antoine) [{'work': 'B.', 'year': '1998', 'page': '602'}]
# 259 VESTIER (Phidias) [{'work': 'B.', 'year': '1997', 'page': '258'}, {'work': 'B.', 'year': '1998', 'page': '386'}]
# 259 Veude, rivière [{'work': 'B.', 'year': '1996', 'page': '686'}]
# 259 Veuves [{'work': 'B.', 'year': '2000', 'page': '53'}, {'work': 'M.', 'number': 'LXIV', 'page': '152'}]
# 259 Vézières (Vienne) [{'work': 'B.', 'year': '1994', 'page': '111'}]
# 259 VIALLE [{'work': 'B.', 'year': '1997', 'page': '312'}]
# 259 Viantaises de Beaulieu (couvent des) [{'work': 'B.', 'year': '1996', 'page': '652'}]
# 259 VIARD (Richard) [{'work': 'B.', 'year': '1998', 'page': '672'}]
# 259 VIART (Jacques de) [{'work': 'B.', 'year': '1995', 'page': '470'}]
# 259 VIART DE VILEETTE (Nicolas) [{'work': 'B.', 'year': '1995', 'page': '469'}]
# 259 VIART DE VOLLAY (Charlotte) [{'work': 'B.', 'year': '1995', 'page': '469'}]
# 259 VIAU (L) [{'work': 'B.', 'year': '1996', 'page': '975'}]
# 259 Vicaria [{'work': 'B.', 'year': '2001', 'page': '48'}]
# 259 Vicolungo (italie) [{'work': 'M.', 'number': 'LXIII', 'page': '176'}]
# 259 VICTOR IV, antipape [{'work': 'M.', 'number': 'LXII', 'page': '128'}]
# 259 VIDART (Jeanne) [{'work': 'B.', 'year': '2000', 'page': '320'}]
# 259 Vidua [{'work': 'B.', 'year': '1995', 'page': '502'}, {'work': 'M.', 'number': 'LXIV', 'page': '152'}]
# 259 Vieil-Baugé [{'work': 'B.', 'year': '2002', 'page': '3'}]
# 259 VIEILLARD (Félix) [{'work': 'B.', 'year': '1999', 'page': '698'}]
# 259 VIEILLARD-BARON (Jean-Louis) [{'work': 'B.', 'year': '1996', 'page': '945'}]
# 259 Vieira (Ludovic) [{'work': 'B.', 'year': '1997', 'page': '40'}, {'work': 'B.', 'year': '1995', 'page': '507'}, {'work': 'B.', 'year': '1998', 'page': '385'}, {'work': 'B.', 'year': '2001', 'page': '12'}, {'work': 'B.', 'year': '1997', 'page': '257'}, {'work': 'B.', 'year': '20901', 'page': '6'}, {'work': 'B.', 'year': '2002', 'page': '165'}]
# 260  -114- Phidias Vestier (1796-1874)", B.1998, 601 sq, ül- "Six manoirs de l'architecte Jacquemin", B.1999, 702 [{'work': 'B.', 'year': '1998', 'page': '601'}, {'work': 'B.', 'year': '1999', 'page': '702'}, {'work': 'B.', 'year': '1996', 'page': '827'}, {'work': 'B.', 'year': '1999', 'page': '1029'}, {'work': 'B.', 'year': '2000', 'page': '391'}, {'work': 'B.', 'year': '2001', 'page': '209'}]
# 260 Public. : " A travers l’histoire locale : quelques célébrités reignacoises ", B.1997, 347 -* Les auberges et hôtelleries de Montbazon", B.1995, 601 -" Biographie de Lilian Whitteker", B.1997, 57" -Le Château de la Bourdaisière”, B.1998. 384 ; B.1998, 666 -"Le château de la Bourdaisière à Montlouis : la demeure des Dames Galantes", B.1999, 1021 -" Le Château de la Tortinière", B.1996, 659, 977 ; B.1998, 666 -" Le château de Montfélix à Saint- Jean-sur-[ndre, commune de Saint-Jean- Saint-Germain” B.2000, 387 -" Le château de Montgauger, historique", B.2000, 384 [{'work': 'B.', 'year': '1997', 'page': '347'}, {'work': 'B.', 'year': '1995', 'page': '601'}, {'work': 'B.', 'year': '1997', 'page': '57'}, {'work': 'B.', 'year': '1998', 'page': '666'}, {'work': 'B.', 'year': '1999', 'page': '1021'}, {'work': 'B.', 'year': '1996', 'page': '659'}, {'work': 'B.', 'year': '1998', 'page': '666'}, {'work': 'B.', 'year': '2000', 'page': '387'}, {'work': 'B.', 'year': '2000', 'page': '384'}, {'work': 'B.', 'year': '1996', 'page': '659'}, {'work': 'B.', 'year': '1998', 'page': '666'}, {'work': 'B.', 'year': '2003', 'page': '236'}, {'work': 'B.', 'year': '1999', 'page': '1024'}, {'work': 'B.', 'year': '2001', 'page': '222'}, {'work': 'B.', 'year': '1997', 'page': '347'}, {'work': 'B.', 'year': '2001', 'page': '222'}, {'work': 'B.', 'year': '1998', 'page': '664'}, {'work': 'B.', 'year': '1998', 'page': '670'}, {'work': 'B.', 'year': '1997', 'page': '55'}, {'work': 'B.', 'year': '2000', 'page': '389'}, {'work': 'B.', 'year': '1998', 'page': '349'}, {'work': 'B.', 'year': '1998', 'page': '66'}, {'work': 'B.', 'year': '1996', 'page': '978'}, {'work': 'B.', 'year': '1997', 'page': '47'}, {'work': 'B.', 'year': '2000', 'page': '388'}, {'work': 'B.', 'year': '1997', 'page': '47'}]
# 261 B.1998, 349 [{'work': 'B.', 'year': '1998', 'page': '349'}, {'work': 'B.', 'year': '2000', 'page': '38'}, {'work': 'B.', 'year': '2003', 'page': '236'}, {'work': 'B.', 'year': '2003', 'page': '236'}, {'work': 'B.', 'year': '2000', 'page': '38'}, {'work': 'B.', 'year': '1997', 'page': '69'}, {'work': 'B.', 'year': '1996', 'page': '978'}, {'work': 'B.', 'year': '1996', 'page': '659'}, {'work': 'B.', 'year': '2003', 'page': '37'}, {'work': 'B.', 'year': '2003', 'page': '236'}, {'work': 'B.', 'year': '2003', 'page': '237'}, {'work': 'B.', 'year': '1997', 'page': '69'}, {'work': 'B.', 'year': '2001', 'page': '11'}, {'work': 'B.', 'year': '1996', 'page': '659'}, {'work': 'B.', 'year': '1997', 'page': '57'}]
# 261 Viel (Claude) [{'work': 'B.', 'year': '1996', 'page': '648'}, {'work': 'B.', 'year': '2002', 'page': '4'}, {'work': 'B.', 'year': '1994', 'page': '285'}, {'work': 'B.', 'year': '2003', 'page': '236'}, {'work': 'B.', 'year': '1996', 'page': '977'}]
# 261 Vienne [{'work': 'B.', 'year': '1996', 'page': '685'}]
# 261 VIEVILLE (André) [{'work': 'B.', 'year': '1998', 'page': '651'}]
# 261 VIGEAN (Mme du) [{'work': 'B.', 'year': '1996', 'page': '943'}]
# 261 VIGER DE JOLLIVAL (François), receveur des tailles à Loches [{'work': 'B.', 'year': '1996', 'page': '859'}]
# 261 VIGIER (Guy, le Jeune) [{'work': 'M.', 'number': 'LXII', 'page': '53'}]
# 261 VIGNEROT DU PLESSIS (Armand-Jean) [{'work': 'B.', 'year': '2001', 'page': '209'}]
# 261 VIGNEROT DU PLESSIS (Louis-François- Armand) [{'work': 'B.', 'year': '2000', 'page': '402'}, {'work': 'B.', 'year': '2002', 'page': '80'}]
# 261 VIGNON (Claude) [{'work': 'B.', 'year': '1995', 'page': '455'}, {'work': 'B.', 'year': '1999', 'page': '1034'}, {'work': 'B.', 'year': '2000', 'page': '395'}, {'work': 'B.', 'year': '2001', 'page': '211'}]
# 261 VIGNY (Alfred de) [{'work': 'B.', 'year': '1997', 'page': '58'}, {'work': 'B.', 'year': '1999', 'page': '986'}]
# 262 -115- VIGUIÉ [{'work': 'B.', 'year': '1997', 'page': '312'}]
# 262 VIGUIER (Jérôme) [{'work': 'B.', 'year': '1997', 'page': '131'}]
# 262 Vijon (Indre) [{'work': 'M.', 'number': 'LXII', 'page': '177'}]
# 262 Villaines-les-Rochers [{'work': 'B.', 'year': '2000', 'page': '370'}, {'work': 'B.', 'year': '2000', 'page': '389'}]
# 262 Villandry [{'work': 'B.', 'year': '1994', 'page': '60'}, {'work': 'B.', 'year': '2000', 'page': '384'}]
# 262 VILLE (Sébastien) [{'work': 'B.', 'year': '1998', 'page': '670'}]
# 262 Ville-aux-Dames (la) [{'work': 'B.', 'year': '1997', 'page': '49'}, {'work': 'B.', 'year': '1998', 'page': '361'}]
# 262 Villebernin [{'work': 'B.', 'year': '2000', 'page': '222'}, {'work': 'B.', 'year': '1999', 'page': '962'}]
# 262 Villedômer [{'work': 'B.', 'year': '2003', 'page': '31'}]
# 262 Villejésus [{'work': 'B.', 'year': '1996', 'page': '809'}]
# 262 Villeloin-Coulangé [{'work': 'B.', 'year': '1997', 'page': '221'}, {'work': 'B.', 'year': '1998', 'page': '562'}, {'work': 'B.', 'year': '1997', 'page': '223'}, {'work': 'B.', 'year': '2000', 'page': '60'}]
# 262 Villentrois [{'work': 'B.', 'year': '2000', 'page': '215'}]
# 262 VILLES (Alain) [{'work': 'B.', 'year': '1997', 'page': '344'}, {'work': 'B.', 'year': '2001', 'page': '219'}, {'work': 'B.', 'year': '2001', 'page': '219'}, {'work': 'B.', 'year': '2000', 'page': '382'}, {'work': 'B.', 'year': '2001', 'page': '219'}]
# 262 Villiers-au-Bouin [{'work': 'B.', 'year': '1994', 'page': '227'}, {'work': 'B.', 'year': '1998', 'page': '506'}, {'work': 'M.', 'number': 'LXIL', 'page': '52'}]
# 262 Villiers-en-Brenne [{'work': 'B.', 'year': '2000', 'page': '220'}]
# 262 Vimaire [{'work': 'B.', 'year': '1998', 'page': '359'}]
# 263 VINCHON (Auguste) [{'work': 'B.', 'year': '2001', 'page': '215'}]
# 263 Vincinaux (Jean-Louis) [{'work': 'B.', 'year': '1996', 'page': '648'}]
# 263 VIOLOT (M) [{'work': 'B.', 'year': '2000', 'page': '384'}]
# 263 VIOT (René) [{'work': 'B.', 'year': '1997', 'page': '284'}]
# 263 VIRARD ($5.) [{'work': 'B.', 'year': '1999', 'page': '1019'}]
# 263 VIRON (R) [{'work': 'B.', 'year': '1996', 'page': '976'}]
# 263 VISCONTI (Ludovico-Tullio) [{'work': 'B.', 'year': '2002', 'page': '168'}]
# 263 VISCONTI (Paul) [{'work': 'B.', 'year': '1997', 'page': '303'}]
# 263 VISSET (L.) [{'work': 'B.', 'year': '2000', 'page': '384'}]
# 263 Vita Martini [{'work': 'B.', 'year': '1995', 'page': '563'}, {'work': 'M.', 'number': 'LXIII', 'page': '27'}]
# 263 VITRY (Bernard), architecte, B.1997, 198, 291; B.1998, 545, 654, 656 [{'work': 'B.', 'year': '1997', 'page': '198'}, {'work': 'B.', 'year': '1998', 'page': '545'}]
# 263 VITRY (François), maçon [{'work': 'B.', 'year': '1994', 'page': '158'}]
# 263 VIVENT (Dorinique} [{'work': 'B.', 'year': '1999', 'page': '1016'}]
# 263 VIVIEN, comte de Tours [{'work': 'B.', 'year': '2000', 'page': '150'}, {'work': 'B.', 'year': '2001', 'page': '47'}, {'work': 'M.', 'number': 'LXIL', 'page': '45'}]
# 263 Vivier (Jack} [{'work': 'B.', 'year': '1996', 'page': '648'}, {'work': 'B.', 'year': '1994', 'page': '311'}, {'work': 'B.', 'year': '2000', 'page': '369'}, {'work': 'B.', 'year': '1996', 'page': '963'}, {'work': 'B.', 'year': '2002', 'page': '4'}, {'work': 'B.', 'year': '2001', 'page': '183'}, {'work': 'B.', 'year': '1997', 'page': '301'}, {'work': 'B.', 'year': '2001', 'page': '13'}, {'work': 'B.', 'year': '1998', 'page': '647'}, {'work': 'B.', 'year': '1994', 'page': '301'}, {'work': 'B.', 'year': '2001', 'page': '223'}, {'work': 'B.', 'year': '1998', 'page': '381'}, {'work': 'B.', 'year': '1997', 'page': '349'}, {'work': 'B.', 'year': '2002', 'page': '13'}, {'work': 'B.', 'year': '1999', 'page': '991'}]
# 264 -116- Archambauit [{'work': 'B.', 'year': '1999', 'page': '1001'}, {'work': 'B.', 'year': '1997', 'page': '349'}]
# 264 "La Résistance en Touraine, les héros de l’ombre du groupe Rabelais", B.1995, 601 [{'work': 'B.', 'year': '1995', 'page': '601'}, {'work': 'B.', 'year': '2001', 'page': '223'}, {'work': 'B.', 'year': '2003', 'page': '221'}, {'work': 'B.', 'year': '1994', 'page': '42'}, {'work': 'B.', 'year': '2001', 'page': '13'}]
# 264 VIVIER (Robert) [{'work': 'B.', 'year': '1997', 'page': '304'}, {'work': 'B.', 'year': '1998', 'page': '654'}, {'work': 'B.', 'year': '2002', 'page': '191'}]
# 264 VIVONNE (Jean de) [{'work': 'B.', 'year': '1996', 'page': '816'}]
# 264 Voie ferrée Tours-Les Sables, B.1994, 200 [{'work': 'B.', 'year': '1994', 'page': '200'}]
# 264 Voie romaine [{'work': 'B.', 'year': '1998', 'page': '404'}, {'work': 'B.', 'year': '1998', 'page': '403'}, {'work': 'B.', 'year': '1999', 'page': '754'}, {'work': 'B.', 'year': '2000', 'page': '115'}, {'work': 'B.', 'year': '1994', 'page': '60'}, {'work': 'B.', 'year': '1998', 'page': '403'}, {'work': 'B.', 'year': '1994', 'page': '60'}, {'work': 'M.', 'number': 'XI', 'page': '31'}]
# 264 VOISIN (docteur) [{'work': 'B.', 'year': '1999', 'page': '991'}, {'work': 'B.', 'year': '1999', 'page': '1011'}]
# 264 Voisin (André-Roger) [{'work': 'B.', 'year': '1997', 'page': '62'}]
# 264 : La soierie en Touraine, B.2000, 41 [{'work': 'B.', 'year': '2000', 'page': '41'}, {'work': 'B.', 'year': '2000', 'page': '385'}, {'work': 'B.', 'year': '1999', 'page': '1025'}, {'work': 'B.', 'year': '2002', 'page': '201'}]
# 264 Voisine (Liliane) [{'work': 'B.', 'year': '2000', 'page': '389'}]
# 264 Voltz (Charles) [{'work': 'B.', 'year': '1996', 'page': '648'}, {'work': 'B.', 'year': '1997', 'page': '64'}]
# 264 VOLUSIEN, évêque de Tours [{'work': 'B.', 'year': '1997', 'page': '123'}]
# 264 VONS (Jacqueline) [{'work': 'B.', 'year': '2002', 'page': '198'}]
# 264 Vou [{'work': 'B.', 'year': '1997', 'page': '170'}, {'work': 'B.', 'year': '2000', 'page': '294'}]
# 264 VOUET (Simon) [{'work': 'B.', 'year': '1998', 'page': '509'}]
# 264 Vouvray [{'work': 'B.', 'year': '1998', 'page': '609'}]
# 264 VOYER (famille de) [{'work': 'B.', 'year': '1996', 'page': '816'}]
# 264 VOYER {marquis de) [{'work': 'B.', 'year': '1995', 'page': '535'}]
# 264 VOYER, receveur, B.1997, 226. [{'work': 'B.', 'year': '1997', 'page': '226'}]
# 265 VOYER DE PAULMY-ARGENSON (Antoine- René) [{'work': 'B.', 'year': '1999', 'page': '1036'}]
# 265 VOYER (Jean) [{'work': 'B.', 'year': '1997', 'page': '170'}]
# 265 VOYER (Pierre) [{'work': 'B.', 'year': '1997', 'page': '170'}]
# 265 VRAY (Nicole) [{'work': 'B.', 'year': '1998', 'page': '666'}]
# 265 VRIGNAUD (Hubert) [{'work': 'B.', 'year': '1999', 'page': '740'}]
# 265 W WALTER (Bertrand) [{'work': 'B.', 'year': '2001', 'page': '219'}]
# 265 WALVEIN, maire de Tours [{'work': 'B.', 'year': '1997', 'page': '241'}]
# 265 Wanecg (Marguerite) [{'work': 'B.', 'year': '2001', 'page': '11'}, {'work': 'B.', 'year': '2000', 'page': '345'}, {'work': 'B.', 'year': '2001', 'page': '222'}]
# 265 WARDEGA (Pierre) [{'work': 'B.', 'year': '1994', 'page': '326'}]
# 265 Warolin (Gilles) [{'work': 'B.', 'year': '1995', 'page': '345'}]
# 265 Wattiez (Jacques) [{'work': 'B.', 'year': '2000', 'page': '42'}, {'work': 'B.', 'year': '1998', 'page': '668'}]
# 265 WEBER (Raymond) [{'work': 'B.', 'year': '2003', 'page': '226'}]
# 265 WEIL (François) [{'work': 'B.', 'year': '1999', 'page': '1025'}]
# 265 WEND (Carmen de) [{'work': 'B.', 'year': '2001', 'page': '213'}]
# 265 WERMELINGER [{'work': 'B.', 'year': '2001', 'page': '183'}]
# 265 Westphal (Christian) [{'work': 'B.', 'year': '1997', 'page': '48'}]
# 265 WETTISTEIN (Janine) [{'work': 'B.', 'year': '1997', 'page': '346'}]
# 265 WHITTEKER (Lilian) [{'work': 'B.', 'year': '1997', 'page': '57'}]
# 265 Wiart (Jean-Paul) [{'work': 'B.', 'year': '1996', 'page': '668'}]
# 265 WILLIACHAIRE [{'work': 'M.', 'number': 'LXII', 'page': '65'}]
# 265 WILLIEZ (Mgr Alfred)) [{'work': 'B.', 'year': '2001', 'page': '172'}]
# 265 WIMILLE [{'work': 'B.', 'year': '2000', 'page': '377'}]
# 265 WITTMANN (Alain) [{'work': 'B.', 'year': '1997', 'page': '344'}, {'work': 'B.', 'year': '2000', 'page': '382'}, {'work': 'B.', 'year': '2002', 'page': '27'}]
# 266 -117- Y YGAUNIN (Jean) [{'work': 'B.', 'year': '2003', 'page': '37'}, {'work': 'B.', 'year': '2003', 'page': '165'}]
# 266 Yron [{'work': 'B.', 'year': '1995', 'page': '357'}]
# 266 YSABEAU [{'work': 'B.', 'year': '2000', 'page': '221'}]
# 266 YSORÉ D'HERVAULT (Mgr Matthieu) [{'work': 'B.', 'year': '1995', 'page': '477'}]
# 266 YVAN (Alexandre) [{'work': 'B.', 'year': '2001', 'page': '146'}]
# 266 B.2002, 3 [{'work': 'B.', 'year': '2002', 'page': '3'}, {'work': 'B.', 'year': '1999', 'page': '701'}, {'work': 'B.', 'year': '1994', 'page': '32'}, {'work': 'B.', 'year': '1995', 'page': '351'}, {'work': 'B.', 'year': '1996', 'page': '647'}, {'work': 'B.', 'year': '1997', 'page': '62'}, {'work': 'B.', 'year': '1998', 'page': '407'}, {'work': 'B.', 'year': '1995', 'page': '602'}, {'work': 'B.', 'year': '1997', 'page': '344'}, {'work': 'B.', 'year': '1997', 'page': '346'}, {'work': 'B.', 'year': '1998', 'page': '664'}]
# 266 YZABEAU (Claude-Alexandre), curé de St-Martin [{'work': 'B.', 'year': '1997', 'page': '191'}]
# 266 Yzeures-sur-Creuse [{'work': 'B.', 'year': '2000', 'page': '214'}, {'work': 'B.', 'year': '1999', 'page': '1015'}, {'work': 'B.', 'year': '2001', 'page': '139'}, {'work': 'B.', 'year': '1998', 'page': '661'}, {'work': 'B.', 'year': '1999', 'page': '678'}, {'work': 'B.', 'year': '1994', 'page': '324'}, {'work': 'M.', 'number': 'LXIV', 'page': '84'}, {'work': 'M.', 'number': 'LXIV', 'page': '143'}]
# 266 YZORÉ (Jacques) [{'work': 'B.', 'year': '1996', 'page': '817'}]
# 267 Z ZADORA-RIO (Elisabeth) [{'work': 'B.', 'year': '1997', 'page': '346'}, {'work': 'B.', 'year': '1996', 'page': '596'}, {'work': 'B.', 'year': '1996', 'page': '976'}, {'work': 'B.', 'year': '1997', 'page': '347'}]
# 268 Zamarlik (Henri) [{'work': 'B.', 'year': '2002', 'page': '12'}]
# 268 704. ZARINI (Mme) [{'work': 'B.', 'year': '2002', 'page': '14'}, {'work': 'B.', 'year': '2003', 'page': '19'}]
# 268 tradition de saint Martin en Croatie", M. ZOCCHETTI {J.) [{'work': 'M.', 'number': 'XI', 'page': '29'}]

# %%
from sat_biblio_referencement.database.database_manager import DatabaseManager

# %%
dbm = DatabaseManager()
dbm.create_database()
dbm.prepare()
session = dbm.get_session()
# Out:
# 2022-11-27 18:15:28,908 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-11-27 18:15:28,910 INFO sqlalchemy.engine.Engine COMMIT
